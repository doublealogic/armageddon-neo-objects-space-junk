# %%
#Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import time
import datetime
import scipy.stats as st
from scipy.stats import linregress

# %%
#Set CSV Path
space_trash_csv = "../CSV_Output/space_trash.csv"

#Read CSV
gdp_trash_df = pd.read_csv(space_trash_csv)

#Print
gdp_trash_df
# Out:
#     Unnamed: 0               Country  Orbital TBA  Orbital Payload Count  \
# 0            0               ALGERIA            0                      6
# 1            1            ARAB WORLD            0                     14
# 2            2             ARGENTINA            0                     24
# 3            3             AUSTRALIA            0                     22
# 4            4               AUSTRIA            0                      3
# 5            5            AZERBAIJAN            0                      3
# 6            6               BELARUS            0                      2
# 7            7               BELGIUM            0                      6
# 8            8               BOLIVIA            0                      1
# 9            9                BRAZIL            0                     17
# 10          10              BULGARIA            0                      1
# 11          11                CANADA            0                     59
# ...

# %%
#define variables
gdp = gdp_trash_df["Value"]
orbital_trash = gdp_trash_df["Orbital Total"]

#calculate and print pearson coefficient
print(f"The r-value is: {round(st.pearsonr(gdp, orbital_trash)[0],2)}")

#set variables for linear regression
x_values = gdp
y_values = orbital_trash
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#chart regression and add labels and title
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('GDP')
plt.ylabel('Space Trash')
plt.title("Linear Regression of GDP vs  Orbital Total Space Trash")

#save chart as png
plt.savefig("../Final_Output/GDP_VS_Orbital).png")

#display chart
plt.show()
# Out:
# The r-value is: 0.95

# %%
#define variables
gdp = gdp_trash_df["Value"]
decayed_trash = gdp_trash_df["Decayed Total"]

#calculate and print pearson coefficient
print(f"The r-value is: {round(st.pearsonr(gdp, decayed_trash)[0],2)}")

#set variables for linear regression
x_values = gdp
y_values = decayed_trash
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#chart regression and add labels and title
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('GDP')
plt.ylabel('Space Trash')
plt.title("Linear Regression of GDP vs  Decayed Total Space Trash")

#save chart as png
plt.savefig("../Final_Output/GDP_VS_Decayed).png")

#display chart
plt.show()
# Out:
# The r-value is: 0.95

# %%
#define variables
gdp = gdp_trash_df["Value"]
total_trash = gdp_trash_df["Total"]

#calculate and print pearson coefficient
print(f"The r-value is: {round(st.pearsonr(gdp, total_trash)[0],2)}")

#set variables for linear regression
x_values = gdp
y_values = total_trash
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#chart regression and add labels and title
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('GDP')
plt.ylabel('Space Trash')
plt.title("Linear Regression of GDP vs Total Space Trash")

#save chart as png
plt.savefig("../Final_Output/GDP_VS_Total).png")

#display chart
plt.show()
# Out:
# The r-value is: 0.95

# %%
#Remove US as outlier
us_drop = gdp_trash_df[gdp_trash_df["Country"] == "UNITED STATES"].index
gdp_minus_us = gdp_trash_df.drop(us_drop)
gdp_minus_us
# Out:
#     Unnamed: 0               Country  Orbital TBA  Orbital Payload Count  \
# 0            0               ALGERIA            0                      6
# 1            1            ARAB WORLD            0                     14
# 2            2             ARGENTINA            0                     24
# 3            3             AUSTRALIA            0                     22
# 4            4               AUSTRIA            0                      3
# 5            5            AZERBAIJAN            0                      3
# 6            6               BELARUS            0                      2
# 7            7               BELGIUM            0                      6
# 8            8               BOLIVIA            0                      1
# 9            9                BRAZIL            0                     17
# 10          10              BULGARIA            0                      1
# 11          11                CANADA            0                     59
# ...

# %%
#define variables
gdp_no_us = gdp_minus_us["Value"]
orbital_trash_no_us = gdp_minus_us["Orbital Total"]

#calculate and print pearson coefficient
print(f"The r-value is: {round(st.pearsonr(gdp_no_us, orbital_trash_no_us)[0],2)}")

#set variables for linear regression
x_values = gdp_no_us
y_values = orbital_trash_no_us
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#chart regression and add labels and title
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('GDP')
plt.ylabel('Space Trash')
plt.title("Linear Regression of GDP vs  Orbital Total Space Trash (No US)")

#save chart as png
plt.savefig("../Final_Output/GDP_VS_Orbital_no_us).png")

#display chart
plt.show()
# Out:
# The r-value is: 0.68

# %%
#define variables
gdp_no_us = gdp_minus_us["Value"]
decayed_trash_no_us = gdp_minus_us["Decayed Total"]

#calculate and print pearson coefficient
print(f"The r-value is: {round(st.pearsonr(gdp_no_us, decayed_trash_no_us)[0],2)}")

#set variables for linear regression
x_values = gdp_no_us
y_values = decayed_trash_no_us
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#chart regression and add labels and title
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('GDP')
plt.ylabel('Space Trash')
plt.title("Linear Regression of GDP vs  Decayed Total Space Trash (No US)")

#save chart as png
plt.savefig("../Final_Output/GDP_VS_Decayed_no_us).png")

#display chart
plt.show()
# Out:
# The r-value is: 0.53

# %%
#define variables
gdp_no_us = gdp_minus_us["Value"]
trash_no_us = gdp_minus_us["Total"]

#calculate and print pearson coefficient
print(f"The r-value is: {round(st.pearsonr(gdp_no_us, trash_no_us)[0],2)}")

#set variables for linear regression
x_values = gdp_no_us
y_values = trash_no_us
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#chart regression and add labels and title
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('GDP')
plt.ylabel('Space Trash')
plt.title("Linear Regression of GDP vs  Decayed Total Space Trash (No US)")

#save chart as png
plt.savefig("../Final_Output/GDP_VS_Total_no_us).png")

#display chart
plt.show()
# Out:
# The r-value is: 0.6
